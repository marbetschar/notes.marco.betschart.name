# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# Import necessary modules:

# %%
import numpy as np
import arviz as az
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
from scipy.special import gamma
import preliz as pz
import matplotlib as mpl
import pymc as pm
import bambi as bmb

# %%
plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = (12,3)

# %% [markdown]
# ## Credit Data

# %% [markdown]
# Read credit data:

# %%
credit_data = pd.read_csv("credit_data.csv")
credit_data.head()
# Out:
#    ID   Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   1   14.891   3606     283      2   34         11    Male      No     Yes
# 1   2  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2   3  104.593   7075     514      4   71         11    Male      No      No
# 3   4  148.924   9504     681      3   36         11  Female      No      No
# 4   5   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 0  Caucasian      333
# 1      Asian      903
# 2      Asian      580
# 3      Asian      964
# 4  Caucasian      331

# %% [markdown]
# Simple linear regression:

# %%
credit_model1 = bmb.Model( "Balance ~ Limit", data=credit_data, family="gaussian" )
credit_trace1 = credit_model1.fit( draws=2000, tune=2000 )
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, Intercept, Limit]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 3 seconds.

# %%
credit_data.plot.scatter( x="Limit", y="Balance", figsize=(8,4) )
bmb.interpret.plot_predictions( credit_model1, credit_trace1, "Limit", prob=0.9, ax=plt.gca() )
# Out:
# Default computed for conditional variable: Limit
# (<Figure size 800x400 with 1 Axes>,
#  array([<Axes: xlabel='Limit', ylabel='Balance'>], dtype=object))

# %%
pm.summary( credit_trace1 )
# Out:
#               mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# sigma      234.301   8.240  218.712  249.734      0.072    0.101   13088.0
# Intercept -292.896  27.004 -342.889 -242.956      0.252    0.285   11464.0
# Limit        0.172   0.005    0.162    0.181      0.000    0.000   11880.0
#
#            ess_tail  r_hat
# sigma        6315.0    1.0
# Intercept    6153.0    1.0
# Limit        6035.0    1.0

# %% [markdown]
# $R^2$ score:

# %%
credit_model1.predict(credit_trace1, kind="response")
ypred = az.extract( credit_trace1.posterior_predictive ).Balance.values.T
ytrue = credit_data.Balance.values
pm.r2_score( ytrue, ypred )
# Out:
# r2        0.659271
# r2_std    0.018800
# dtype: float64

# %% [markdown]
# Posterior predictive check:

# %%
credit_model1.predict( credit_trace1, kind="response" )
pm.plot_ppc( credit_trace1, num_pp_samples=500 );

# %% [markdown]
# ## More than one variable

# %%
credit_data.head()
# Out:
#    ID   Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   1   14.891   3606     283      2   34         11    Male      No     Yes
# 1   2  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2   3  104.593   7075     514      4   71         11    Male      No      No
# 3   4  148.924   9504     681      3   36         11  Female      No      No
# 4   5   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 0  Caucasian      333
# 1      Asian      903
# 2      Asian      580
# 3      Asian      964
# 4  Caucasian      331

# %%
credit_model2 = bmb.Model( "Balance ~ Limit + Income", data=credit_data, family="gaussian" )
credit_trace2 = credit_model2.fit(draws=2000, tune=2000)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, Intercept, Limit, Income]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 4 seconds.

# %%
credit_model2
# Out:
#        Formula: Balance ~ Limit + Income
#         Family: gaussian
#           Link: mu = identity
#   Observations: 400
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 520.015, sigma: 3008.889)
#             Limit ~ Normal(mu: 0.0, sigma: 0.498)
#             Income ~ Normal(mu: 0.0, sigma: 32.6123)
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 459.1838)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
pm.summary( credit_trace2 )
# Out:
#               mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# sigma      165.992   5.829  154.790  176.602      0.070    0.065    7017.0
# Intercept -384.829  19.553 -422.045 -349.120      0.208    0.178    8818.0
# Limit        0.264   0.006    0.253    0.275      0.000    0.000    6517.0
# Income      -7.661   0.388   -8.361   -6.927      0.005    0.004    6345.0
#
#            ess_tail  r_hat
# sigma        5490.0    1.0
# Intercept    7337.0    1.0
# Limit        5799.0    1.0
# Income       5867.0    1.0

# %%
credit_model2.predict(credit_trace2, kind="response")
ypred = az.extract( credit_trace2.posterior_predictive ).Balance.values.T
ytrue = credit_data.Balance.values
pm.r2_score( ytrue, ypred )
# Out:
# r2        0.793596
# r2_std    0.012851
# dtype: float64

# %% [markdown]
# Significantly more variance explained with `Income` data.

# %% [markdown]
# Posterior predictive check:

# %%
credit_model2.predict( credit_trace2, kind="response" )
pm.plot_ppc( credit_trace2, num_pp_samples=500 );

# %% [markdown]
# ## Categorical Predictors

# %%
credit_data[["Balance", "Income", "Limit", "Student"]].head()
# Out:
#    Balance   Income  Limit Student
# 0      333   14.891   3606      No
# 1      903  106.025   6645     Yes
# 2      580  104.593   7075      No
# 3      964  148.924   9504      No
# 4      331   55.882   4897      No

# %%
credit_model3 = bmb.Model( "Balance ~ Limit + Income + Student", data=credit_data, family="gaussian" )
credit_trace3 = credit_model3.fit(draws=2000, tune=2000)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, Intercept, Limit, Income, Student]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 4 seconds.

# %%
pm.summary( credit_trace3 )
# Out:
#                  mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# sigma         104.707   3.768   97.419  111.621      0.039    0.044    9177.0
# Intercept    -432.226  12.407 -455.250 -408.598      0.128    0.118    9336.0
# Limit           0.268   0.004    0.261    0.274      0.000    0.000    6657.0
# Income         -7.901   0.240   -8.340   -7.436      0.003    0.003    6597.0
# Student[Yes]  427.391  17.263  393.839  458.592      0.185    0.198    8695.0
#
#               ess_tail  r_hat
# sigma           5961.0    1.0
# Intercept       6945.0    1.0
# Limit           5326.0    1.0
# Income          5554.0    1.0
# Student[Yes]    5158.0    1.0

# %%
credit_model3.predict(credit_trace3, kind="response")
ypred = az.extract( credit_trace3.posterior_predictive ).Balance.values.T
ytrue = credit_data.Balance.values
pm.r2_score( ytrue, ypred )
# Out:
# r2        0.906215
# r2_std    0.006383
# dtype: float64

# %% [markdown]
# Again a significant improvement! Student status explains a lot of variance!

# %% [markdown]
# Posterior predictive check:

# %%
credit_model3.predict( credit_trace3, kind="response" )
pm.plot_ppc( credit_trace3, num_pp_samples=500 );

# %% [markdown]
# ## Full 'Enchilada'
#
# (all variables)

# %%
credit_data.head()
# Out:
#    ID   Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   1   14.891   3606     283      2   34         11    Male      No     Yes
# 1   2  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2   3  104.593   7075     514      4   71         11    Male      No      No
# 3   4  148.924   9504     681      3   36         11  Female      No      No
# 4   5   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 0  Caucasian      333
# 1      Asian      903
# 2      Asian      580
# 3      Asian      964
# 4  Caucasian      331

# %%
credit_model4 = bmb.Model( 
    "Balance ~ Income + Limit + Rating + Cards + Age + Education + Gender + Student + Married + Ethnicity", 
    data=credit_data, 
    family="gaussian" 
)
credit_trace4 = credit_model4.fit(draws=2000, tune=2000)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, Intercept, Income, Limit, Rating, Cards, Age, Education, Gender, Student, Married, Ethnicity]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 22 seconds.

# %%
summary = pm.summary( credit_trace4 )
summary
# Out:
#                          mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# sigma                  99.101   3.615   92.777  106.353      0.035    0.045
# Intercept            -479.520  36.047 -544.409 -408.119      0.369    0.421
# Income                 -7.804   0.237   -8.257   -7.362      0.002    0.003
# Limit                   0.190   0.033    0.129    0.252      0.000    0.000
# Rating                  1.151   0.494    0.217    2.061      0.007    0.005
# Cards                  17.604   4.379    9.161   25.706      0.052    0.046
# Age                    -0.613   0.295   -1.156   -0.043      0.003    0.003
# Education              -1.108   1.604   -4.015    1.967      0.015    0.021
# Gender[Female]        -10.645   9.826  -29.074    7.623      0.089    0.118
# Student[Yes]          425.743  16.821  394.382  457.340      0.164    0.201
# Married[Yes]           -8.645  10.609  -28.355   11.154      0.106    0.139
# Ethnicity[Asian]       17.185  14.309  -10.261   43.917      0.163    0.155
# Ethnicity[Caucasian]   10.215  12.329  -13.387   32.971      0.145    0.140
#
#                       ess_bulk  ess_tail  r_hat
# sigma                  10451.0    5576.0    1.0
# Intercept               9586.0    6132.0    1.0
# Income                 10562.0    5103.0    1.0
# Limit                   5265.0    5766.0    1.0
# Rating                  5197.0    5691.0    1.0
# Cards                   7036.0    6061.0    1.0
# Age                    10230.0    5772.0    1.0
# Education              11960.0    5291.0    1.0
# Gender[Female]         12274.0    5667.0    1.0
# Student[Yes]           10585.0    6111.0    1.0
# Married[Yes]           10064.0    5091.0    1.0
# Ethnicity[Asian]        7706.0    6054.0    1.0
# Ethnicity[Caucasian]    7282.0    5795.0    1.0

# %%
credit_data.Ethnicity.unique()
# Out:
# array(['Caucasian', 'Asian', 'African American'], dtype=object)

# %% [markdown]
# Only significant predictors:

# %%
summary[summary["hdi_3%"] * summary["hdi_97%"] > 0]
# Out:
#                  mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# sigma          99.101   3.615   92.777  106.353      0.035    0.045   10451.0
# Intercept    -479.520  36.047 -544.409 -408.119      0.369    0.421    9586.0
# Income         -7.804   0.237   -8.257   -7.362      0.002    0.003   10562.0
# Limit           0.190   0.033    0.129    0.252      0.000    0.000    5265.0
# Rating          1.151   0.494    0.217    2.061      0.007    0.005    5197.0
# Cards          17.604   4.379    9.161   25.706      0.052    0.046    7036.0
# Age            -0.613   0.295   -1.156   -0.043      0.003    0.003   10230.0
# Student[Yes]  425.743  16.821  394.382  457.340      0.164    0.201   10585.0
#
#               ess_tail  r_hat
# sigma           5576.0    1.0
# Intercept       6132.0    1.0
# Income          5103.0    1.0
# Limit           5766.0    1.0
# Rating          5691.0    1.0
# Cards           6061.0    1.0
# Age             5772.0    1.0
# Student[Yes]    6111.0    1.0

# %% [markdown]
# Performance:

# %%
credit_model4.predict(credit_trace4, kind="response")
ypred = az.extract( credit_trace4.posterior_predictive ).Balance.values.T
ytrue = credit_data.Balance.values
pm.r2_score( ytrue, ypred )
# Out:
# r2        0.915310
# r2_std    0.005887
# dtype: float64

# %% [markdown]
# Posterior predictive test:

# %%
credit_model4.predict( credit_trace4, kind="response" )
pm.plot_ppc( credit_trace4, num_pp_samples=500 );

# %% [markdown]
# ## Interactions

# %% [markdown]
# Read data:

# %%
adv_data = pd.read_csv("advertising.csv")
adv_data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# Marginal plots:

# %%
fig, ax = plt.subplots( 1, 3, figsize=(12,3), sharey=True )
for i, x in enumerate(['TV', 'radio', 'newspaper']):
    sns.scatterplot( data=adv_data, x=x, y="sales", ax=ax[i] )

# %% [markdown]
# Fit a model without interactions:

# %%
adv_model1 = bmb.Model( "sales ~ TV + radio + newspaper", data=adv_data, family="gaussian" )
adv_trace1 = adv_model1.fit(draws=2000, tune=2000)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, Intercept, TV, radio, newspaper]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 3 seconds.

# %%
pm.summary( adv_trace1 )
# Out:
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# sigma      1.695  0.087   1.533    1.857      0.001    0.001   10905.0
# Intercept  2.941  0.316   2.368    3.551      0.003    0.004   13486.0
# TV         0.046  0.001   0.043    0.048      0.000    0.000   13744.0
# radio      0.189  0.009   0.172    0.205      0.000    0.000    8291.0
# newspaper -0.001  0.006  -0.012    0.010      0.000    0.000    9108.0
#
#            ess_tail  r_hat
# sigma        6919.0    1.0
# Intercept    6937.0    1.0
# TV           7236.0    1.0
# radio        6417.0    1.0
# newspaper    6804.0    1.0

# %% [markdown]
# newspaper is not significant at the 94% level (HDI includes zero).

# %% [markdown]
# $R^2$ and RMSE:

# %%
adv_model1.predict(adv_trace1, kind="response")
ypred = az.extract( adv_trace1.posterior_predictive ).sales.values.T
ytrue = adv_data.sales.values
pm.r2_score( ytrue, ypred )
# Out:
# r2        0.826769
# r2_std    0.015695
# dtype: float64

# %%
np.sqrt( np.mean( (ypred-ytrue)**2 ) )
# Out:
# np.float64(2.3915150703391395)

# %% [markdown]
# Residual contour plot to motivate interaction:

# %%
mean_residuals = np.mean( ytrue-ypred, axis=0 )
mean_residuals.shape
# Out:
# (200,)

# %%
plt.figure( figsize=(8,4) )
sns.scatterplot(data=adv_data, x="TV", y="radio", hue=mean_residuals, palette="Greens")
plt.title("Mean residuals $\hat{y}_i - y_i$")
# Out:
# Text(0.5, 1.0, 'Mean residuals $\\hat{y}_i - y_i$')

# %% [markdown]
# Posterior predictive test:

# %%
adv_model1.predict( adv_trace1, kind="response" )
pm.plot_ppc( adv_trace1, num_pp_samples=500 );

# %% [markdown]
# Model with interaction:

# %%
adv_model2 = bmb.Model( "sales ~ TV + radio + TV:radio", data=adv_data, family="gaussian" )
adv_trace2 = adv_model2.fit(draws=2000, tune=2000)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, Intercept, TV, radio, TV:radio]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 5 seconds.

# %%
pm.summary( adv_trace2 )
# Out:
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# sigma      0.949  0.048   0.863    1.040      0.001    0.001    7155.0
# Intercept  6.749  0.250   6.293    7.227      0.004    0.003    3311.0
# TV         0.019  0.002   0.016    0.022      0.000    0.000    3171.0
# radio      0.029  0.009   0.013    0.046      0.000    0.000    3134.0
# TV:radio   0.001  0.000   0.001    0.001      0.000    0.000    2917.0
#
#            ess_tail  r_hat
# sigma        5841.0    1.0
# Intercept    4465.0    1.0
# TV           4130.0    1.0
# radio        4233.0    1.0
# TV:radio     3831.0    1.0

# %% [markdown]
# Interaction between TV and radio is significant.

# %% [markdown]
# Change in $R^2$ and RMSE:

# %%
adv_model2.predict(adv_trace2, kind="response")
ypred = az.extract( adv_trace2.posterior_predictive ).sales.values.T
ytrue = adv_data.sales.values
pm.r2_score( ytrue, ypred )
# Out:
# r2        0.938248
# r2_std    0.006096
# dtype: float64

# %%
np.sqrt( np.mean( (ytrue-ypred)**2 ) )
# Out:
# np.float64(1.3392983394061955)

# %% [markdown]
# Posterior predictive test:

# %%
adv_model2.predict( adv_trace2, kind="response" )
pm.plot_ppc( adv_trace2, num_pp_samples=500 );
